# %%
# load sample dataset
from pycaret.datasets import get_data
data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
from pycaret.classification import *
s = setup(data, target = 'Class variable')
# Out:
# <style type="text/css">
# #T_c257b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c257b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c257b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c257b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c257b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c257b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c257b_row0_col1" class="data row0 col1" >8233</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c257b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c257b_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c257b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c257b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c257b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c257b_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c257b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c257b_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c257b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c257b_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c257b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c257b_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c257b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c257b_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c257b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_c257b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c257b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_c257b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c257b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_c257b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c257b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_c257b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c257b_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_c257b_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c257b_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_c257b_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c257b_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_c257b_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c257b_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_c257b_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c257b_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_c257b_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c257b_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_c257b_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c257b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c257b_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_c257b_row18_col1" class="data row18 col1" >d621</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import *
s = setup(data, target = 'Class variable', session_id = 123)
# Out:
# <style type="text/css">
# #T_69cf7_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_69cf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69cf7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_69cf7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69cf7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69cf7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_69cf7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69cf7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_69cf7_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69cf7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_69cf7_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69cf7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_69cf7_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69cf7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_69cf7_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69cf7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_69cf7_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69cf7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_69cf7_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69cf7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_69cf7_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69cf7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_69cf7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_69cf7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_69cf7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_69cf7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_69cf7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_69cf7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_69cf7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_69cf7_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_69cf7_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_69cf7_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_69cf7_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_69cf7_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_69cf7_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_69cf7_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_69cf7_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_69cf7_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_69cf7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_69cf7_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_69cf7_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_69cf7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_69cf7_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_69cf7_row18_col1" class="data row18 col1" >9761</td>
#     </tr>
#   </tbody>
# </table>

# %%
# functional API
best = compare_models()
# Out:
# <style type="text/css">
# #T_3b03e th {
#   text-align: left;
# }
# #T_3b03e_row0_col0, #T_3b03e_row0_col2, #T_3b03e_row0_col3, #T_3b03e_row0_col4, #T_3b03e_row1_col0, #T_3b03e_row1_col1, #T_3b03e_row1_col3, #T_3b03e_row1_col5, #T_3b03e_row1_col6, #T_3b03e_row1_col7, #T_3b03e_row2_col0, #T_3b03e_row2_col1, #T_3b03e_row2_col2, #T_3b03e_row2_col3, #T_3b03e_row2_col4, #T_3b03e_row2_col5, #T_3b03e_row2_col6, #T_3b03e_row2_col7, #T_3b03e_row3_col0, #T_3b03e_row3_col1, #T_3b03e_row3_col2, #T_3b03e_row3_col3, #T_3b03e_row3_col4, #T_3b03e_row3_col5, #T_3b03e_row3_col6, #T_3b03e_row3_col7, #T_3b03e_row4_col0, #T_3b03e_row4_col1, #T_3b03e_row4_col2, #T_3b03e_row4_col4, #T_3b03e_row4_col5, #T_3b03e_row4_col6, #T_3b03e_row4_col7, #T_3b03e_row5_col0, #T_3b03e_row5_col1, #T_3b03e_row5_col2, #T_3b03e_row5_col3, #T_3b03e_row5_col4, #T_3b03e_row5_col5, #T_3b03e_row5_col6, #T_3b03e_row5_col7, #T_3b03e_row6_col0, #T_3b03e_row6_col1, #T_3b03e_row6_col2, #T_3b03e_row6_col3, #T_3b03e_row6_col4, #T_3b03e_row6_col5, #T_3b03e_row6_col6, #T_3b03e_row6_col7, #T_3b03e_row7_col0, #T_3b03e_row7_col1, #T_3b03e_row7_col2, #T_3b03e_row7_col3, #T_3b03e_row7_col4, #T_3b03e_row7_col5, #T_3b03e_row7_col6, #T_3b03e_row7_col7, #T_3b03e_row8_col0, #T_3b03e_row8_col1, #T_3b03e_row8_col2, #T_3b03e_row8_col3, #T_3b03e_row8_col4, #T_3b03e_row8_col5, #T_3b03e_row8_col6, #T_3b03e_row8_col7, #T_3b03e_row9_col0, #T_3b03e_row9_col1, #T_3b03e_row9_col2, #T_3b03e_row9_col3, #T_3b03e_row9_col4, #T_3b03e_row9_col5, #T_3b03e_row9_col6, #T_3b03e_row9_col7, #T_3b03e_row10_col0, #T_3b03e_row10_col1, #T_3b03e_row10_col2, #T_3b03e_row10_col3, #T_3b03e_row10_col4, #T_3b03e_row10_col5, #T_3b03e_row10_col6, #T_3b03e_row10_col7, #T_3b03e_row11_col0, #T_3b03e_row11_col1, #T_3b03e_row11_col2, #T_3b03e_row11_col3, #T_3b03e_row11_col4, #T_3b03e_row11_col5, #T_3b03e_row11_col6, #T_3b03e_row11_col7, #T_3b03e_row12_col0, #T_3b03e_row12_col1, #T_3b03e_row12_col2, #T_3b03e_row12_col3, #T_3b03e_row12_col4, #T_3b03e_row12_col5, #T_3b03e_row12_col6, #T_3b03e_row12_col7, #T_3b03e_row13_col0, #T_3b03e_row13_col1, #T_3b03e_row13_col2, #T_3b03e_row13_col3, #T_3b03e_row13_col4, #T_3b03e_row13_col5, #T_3b03e_row13_col6, #T_3b03e_row13_col7, #T_3b03e_row14_col0, #T_3b03e_row14_col1, #T_3b03e_row14_col2, #T_3b03e_row14_col3, #T_3b03e_row14_col4, #T_3b03e_row14_col5, #T_3b03e_row14_col6, #T_3b03e_row14_col7 {
#   text-align: left;
# }
# #T_3b03e_row0_col1, #T_3b03e_row0_col5, #T_3b03e_row0_col6, #T_3b03e_row0_col7, #T_3b03e_row1_col2, #T_3b03e_row1_col4, #T_3b03e_row4_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3b03e_row0_col8, #T_3b03e_row3_col8, #T_3b03e_row4_col8, #T_3b03e_row5_col8, #T_3b03e_row6_col8, #T_3b03e_row7_col8, #T_3b03e_row8_col8, #T_3b03e_row10_col8, #T_3b03e_row11_col8, #T_3b03e_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3b03e_row1_col8, #T_3b03e_row2_col8, #T_3b03e_row9_col8, #T_3b03e_row13_col8, #T_3b03e_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3b03e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b03e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3b03e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3b03e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3b03e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3b03e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3b03e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3b03e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3b03e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3b03e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b03e_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_3b03e_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_3b03e_row0_col1" class="data row0 col1" >0.7689</td>
#       <td id="T_3b03e_row0_col2" class="data row0 col2" >0.8047</td>
#       <td id="T_3b03e_row0_col3" class="data row0 col3" >0.5602</td>
#       <td id="T_3b03e_row0_col4" class="data row0 col4" >0.7208</td>
#       <td id="T_3b03e_row0_col5" class="data row0 col5" >0.6279</td>
#       <td id="T_3b03e_row0_col6" class="data row0 col6" >0.4641</td>
#       <td id="T_3b03e_row0_col7" class="data row0 col7" >0.4736</td>
#       <td id="T_3b03e_row0_col8" class="data row0 col8" >0.3470</td>
#     </tr>
#     <tr>
#       <th id="T_3b03e_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_3b03e_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_3b03e_row1_col1" class="data row1 col1" >0.7670</td>
#       <td id="T_3b03e_row1_col2" class="data row1 col2" >0.8060</td>
#       <td id="T_3b03e_row1_col3" class="data row1 col3" >0.5497</td>
#       <td id="T_3b03e_row1_col4" class="data row1 col4" >0.7235</td>
#       <td id="T_3b03e_row1_col5" class="data row1 col5" >0.6221</td>
#       <td id="T_3b03e_row1_col6" class="data row1 col6" >0.4581</td>
#       <td id="T_3b03e_row1_col7" class="data row1 col7" >0.4690</td>
#       <td id="T_3b03e_row1_col8" class="data row1 col8" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_3b03e_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_3b03e_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3b03e_row2_col1" class="data row2 col1" >0.7670</td>
#       <td id="T_3b03e_row2_col2" class="data row2 col2" >0.8055</td>
#       <td id="T_3b03e_row2_col3" class="data row2 col3" >0.5550</td>
#       <td id="T_3b03e_row2_col4" class="data row2 col4" >0.7202</td>
#       <td id="T_3b03e_row2_col5" class="data row2 col5" >0.6243</td>
#       <td id="T_3b03e_row2_col6" class="data row2 col6" >0.4594</td>
#       <td id="T_3b03e_row2_col7" class="data row2 col7" >0.4695</td>
#       <td id="T_3b03e_row2_col8" class="data row2 col8" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_3b03e_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_3b03e_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_3b03e_row3_col1" class="data row3 col1" >0.7485</td>
#       <td id="T_3b03e_row3_col2" class="data row3 col2" >0.7911</td>
#       <td id="T_3b03e_row3_col3" class="data row3 col3" >0.5284</td>
#       <td id="T_3b03e_row3_col4" class="data row3 col4" >0.6811</td>
#       <td id="T_3b03e_row3_col5" class="data row3 col5" >0.5924</td>
#       <td id="T_3b03e_row3_col6" class="data row3 col6" >0.4150</td>
#       <td id="T_3b03e_row3_col7" class="data row3 col7" >0.4238</td>
#       <td id="T_3b03e_row3_col8" class="data row3 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_3b03e_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_3b03e_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_3b03e_row4_col1" class="data row4 col1" >0.7427</td>
#       <td id="T_3b03e_row4_col2" class="data row4 col2" >0.7955</td>
#       <td id="T_3b03e_row4_col3" class="data row4 col3" >0.5702</td>
#       <td id="T_3b03e_row4_col4" class="data row4 col4" >0.6543</td>
#       <td id="T_3b03e_row4_col5" class="data row4 col5" >0.6043</td>
#       <td id="T_3b03e_row4_col6" class="data row4 col6" >0.4156</td>
#       <td id="T_3b03e_row4_col7" class="data row4 col7" >0.4215</td>
#       <td id="T_3b03e_row4_col8" class="data row4 col8" >0.3050</td>
#     </tr>
#     <tr>
#       <th id="T_3b03e_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_3b03e_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_3b03e_row5_col1" class="data row5 col1" >0.7410</td>
#       <td id="T_3b03e_row5_col2" class="data row5 col2" >0.7993</td>
#       <td id="T_3b03e_row5_col3" class="data row5 col3" >0.5278</td>
#       <td id="T_3b03e_row5_col4" class="data row5 col4" >0.6630</td>
#       <td id="T_3b03e_row5_col5" class="data row5
